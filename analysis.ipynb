# %% [raw]
# ДИСПЕРСИОННЫЙ АНАЛИЗ ИЗМЕНЕНИЙ МАССЫ ТЕЛА В ТРЁХ ГРУППАХ С ПРИМЕНЕНИЕМ РАЗНЫХ ВИДОВ ДИЕТ

# %% [raw]
# 1. Набор данных
#
# Данные взяты с сайта https://www.sheffield.ac.uk/mash/statistics/datasets (Diet), таблица содержит информацию о 78 участниках исследования со следующими значениями:
# - номер участника исследования
# - пол (0=м, 1=ж)
# - возраст
# - рост
# - масса тела до начала диеты
# - диета (1/2/3)
# - масса тела после шести недель диеты
# Следует отметить, что в столбце pre.weight (масса тела до начала диеты) указаны значения без десятых долей, в отличие от столбца weight6weeks (масса тела после шести недель диеты). Это указывает на приблизительные измерения массы тела участников до начала испытания и более точные измерения после его окончания.
# Для анализа в качестве зависимой переменной будет использоваться разность значений в столбцах G и E, то есть разница массы тела каждого участника до и после диеты. Выбранный уровень значимости во всех случаях равен 0.05.

# %% [markdown]
# ![Образец данных](dataset_example.png)

# %%
import numpy as np
diet_1 = np.array([-3.8, -6, -0.7, -2.9, -2.8, -2, -2, -8.5, -1.9, -3.1, -1.5, -3, -3.6, -0.9, 0.6, -1.1, -4.5, -4.1, -9, -2.4, -3.9, -3.5, -5.1, -3.5])
diet_2 = np.array([0, 0, 2.1, -2, -1.7, -4.3, -7, -0.6, -2.7, -3.6, -3, -2, -4.2, -4.7, -3.3, 0.5, -4.2, -2.4, -5.8, -3.5, -5.3, -1.7, -5.4, -6.1, -7.9, 1.4, -4.3])
diet_3 = np.array([-7, -5.6, -3.4, -6.8, -7.8, -5.4, -6.8, -7.2, -7, -7.3, -0.9, -7.6, -4.1, -6.3, -5, -2.5, -0.9, -3.5, -0.5, -2.8, -8.6, -4.5, -2.8, -4.1, -5.3, -9.2, -6.1])

# %% [raw]
# 2. Оценка применимости дисперсионного анализа
#
# Перед применением дисперсионного анализа необходимо оценить соответствие набора данных нормальному распределению, а также однородность дисперсий в различных группах.

# %% [raw]
# 2.1 Визуализация
#
# При помощи инструментов библиотеки matplotlib получена гистограмма распределения значений в виде колокола, приблизительно соответствующая нормальному распределению.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

data = np.concatenate((diet_1, diet_2, diet_3))
n, bin, patches = plt.hist(data, bins=6)
plt.title('Потеря веса в результате диеты')
plt.xlabel('Разница массы тела до и после диеты, кг')
plt.ylabel('Частота')
plt.show()

# %% [raw]
# 2.2 Проверка нормальности распределения
#
# Для более точной оценки использован тест Шапиро Уилка.
# - Нулевая гипотеза H0: случайная величина распределена нормально.
# - Альтернативная гипотеза H1: распределение не является нормальным.
# Полученное p-значение (0.80) больше, чем α = 0.05, поэтому принимается нулевая гипотеза о нормальности распределения наблюдаемых значений.

# %%
from scipy import stats
stats.shapiro(data)
# Out:
# ShapiroResult(statistic=0.9899080991744995, pvalue=0.8019816875457764)

# %% [raw]
# 2.3 Проверка однородности дисперсий
#
# Так как объём выборок различается, а число выборок больше двух, для проверки используем критерий Бартлетта.
# - Нулевая гипотеза H0: дисперсии рассматриваемых выборок однородны.
# - Альтернативная гипотеза H1: по крайней мере у двух выборок дисперсии не совпадают.
# Полученное p-значение (0.84) больше, чем α = 0.05, поэтому принимается нулевая гипотеза об однородности дисперсий.

# %%
print(len(diet_1))
print(len(diet_2))
print(len(diet_3))
# Out:
# 24
# 27
# 27

# %%
stats.bartlett(diet_1, diet_2, diet_3)
# Out:
# BartlettResult(statistic=0.337454630479139, pvalue=0.8447392194944549)

# %% [raw]
# 3. Однофакторный дисперсионный анализ
#
# 3.1 Анализ зависимости результатов от вида диеты
#
# Проведём однофакторный дисперсионный анализ зависимости между разницей массы тела до и после диеты и видом диеты.
# - Нулевая гипотеза H0: изменение массы тела участников исследования одинаково для всех трёх групп с разными диетами.
# - Альтернативная гипотеза H1: существуют статистически значимые различия в результатах трёх групп.
# Полученное p-значение (0.003) меньше, чем α = 0.05. Также наблюдаемое значение критерия Фишера (6.197) больше, чем табличное (3.119), то есть лежит в области принятия альтернативной гипотезы о том, что результаты в трёх группах статистически значимо различаются.

# %%
stats.f_oneway(diet_1, diet_2, diet_3)
# Out:
# F_onewayResult(statistic=6.1974474531653545, pvalue=0.0032290142385893524)

# %%
# табличное значение критерия Фишера (v1=2, v2=75)
Ft = stats.f.ppf(q=1-0.05, dfn=2, dfd=75)
print(f"{Ft=}")
# Out:
# Ft=3.118642128006125

# %% [raw]
# 3.2 Анализ влияния возраста участников на результаты
#
# Проведём дополнительный анализ, чтобы исключить один из возможных факторов, который мог бы привести к ошибке первого рода. Для этого исключим зависимость между разницей массы тела до и после диеты и возрастом участников испытания.
# - Нулевая гипотеза H0: изменение массы тела участников исследования одинаково для разных возрастных групп.
# - Альтернативная гипотеза H1: существуют статистически значимые различия в результатах разных возрастных групп.
# Данные были отсортированы по возрасту участников и разделены на три равных по объёму группы (по 26 значений): 16-35, 36-43 и 44-60 лет. Полученное p-значение (0.911) значительно больше, чем α = 0.05, а наблюдаемое значение критерия Фишера (0.093) меньше, чем табличное (3.119). Таким образом, изменение массы тела участников исследования из разных возрастных групп не обнаруживает статистически значимых различий.

# %%
age_1 = np.array([-4.2, -7, -5.4, -3.4, -6.8, -3.8, -2.4, -8.6, -8.5, -5.3, -1.9, -3.5, 0.5, -3.3, -4.3, -2.8, -2.7, -1.1, -0.9, 0, -3.5, -2.9, -7.6, -6.8, -5.6, -2.8])
age_2 = np.array([-7.8, -2.5, -7.9, -7.3, -4.7, -2, -2, -1.7, -0.9, -0.5, -2.4, -5.1, 0.6, 1.4, -9.2, -6.1, -4.5, -4.5, -3.5, -5, -3.6, -1.7, 0, -3.5, -9, -4.3])
age_3 = np.array([-5.4, 2.1, -7.2, -5.3, -3.1, -6, -0.9, -6.3, -3, -2, -4.1, -4.1, -3, -2.8, -2, -7, -6.1, -4.2, -0.6, -3.9, -5.8, -3.6, -0.7, -4.1, -7, -1.5])
stats.f_oneway(age_1, age_2, age_3)
# Out:
# F_onewayResult(statistic=0.09289748624901832, pvalue=0.9113916061623499)

# %% [raw]
# 4. Вывод
#
# Полученные при помощи однофакторного дисперсионного анализа результаты доказывают статистически значимое различие влияния на массу тела разных видов диет. Для выявления наиболее эффективной диеты и различий между отдельными видами диет необходимы дополнительные вычисления, так как дисперсионный анализ не позволяет получить подобную дополнительную информацию.
